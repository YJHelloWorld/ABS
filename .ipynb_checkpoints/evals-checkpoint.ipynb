# %%
import healpy as hp
import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#import sys 
#sys.path.append('/home/yao/Desktop/EM-smica/smica-codes/programs') 
#from smica_simulation_new import power_spectrum
import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt

from NPTFit import create_mask as cm
mask = cm.make_mask_total(512,band_mask=True, band_mask_range = 10)
z = np.ones(len(mask))
fr = 1-np.dot(mask,z)/len(mask)

def bin_l(cl):
    bin_averages = []
    for q in range(Q):
        bin_averages.append(sum(cl[q*L/Q:((q+1)*L/Q)]/(L/Q)))
    return bin_averages
        
L = 1500; Q=50;Nf=7; E_cut=0.5; D_B = [];  SamNum = 1;  Evals = np.ones((Q,Nf));Delta = 0.00434117706763*20

for n in range(SamNum):
    D_B_n = []; 
    D = np.load('/home/yao/Desktop/EM-smica/ABS/simulation/total_power_spectrum_masked_NO%s.npy'%(n+1))
    noise_ps = np.load('/home/yao/Desktop/EM-smica/ABS/simulation/noise_power_spectrum.npy')
    CMB = np.load('/home/yao/Desktop/EM-smica/ABS/simulation/cmb_power_spectrum_masked.npy')
    
    D = bin_l(D); CMB = bin_l(CMB); noise_ps = bin_l(noise_ps*fr)  #*fr
    noise = np.zeros_like(noise_ps);f = []
    for i in range(Q):
        f_q = np.ones(Nf)
        for j in range(Nf):
            noise[i][j,j] = noise_ps[i][j,j]*np.sqrt(2.0/((2*i+1)*fr)*L/Q) # *fr
            f_q[j] = f_q[j]/np.sqrt(noise[i][j,j])
        f.append(f_q)
          
    for l in range(Q):
        D[l] = D[l] - noise_ps[l]
        for i in range(Nf): 
            for j in range(Nf):
                D[l][i,j] = D[l][i,j]/np.sqrt(noise[l][i,i]*noise[l][j,j]) + Delta*f[l][i]*f[l][j] 
                
    for l in range(Q): 
        e_vals,E = LA.eig(D[l])
        if n == 0:
            Evals[l,:] = e_vals
        for i in range(Nf):
            E[:,i]=E[:,i]/LA.norm(E[:,i])**2  
        
        D_B_l = 0
        for i in range(Nf):
            if e_vals[i]>=E_cut:
                G_i = np.dot(f[l],E[:,i])
                D_B_l = D_B_l + (G_i**2/e_vals[i]) 
        D_B_l = 1/ D_B_l - Delta
        D_B_n.append(D_B_l)
    D_B.append(D_B_n)
#np.save('/home/yao/Desktop/EM-smica/ABS/results/D_B_1.npy',D_B)

# plt.figure(figsize=(20,15))
for n in range(SamNum):           
    ell = np.ones(Q)
    for q in range(Q):
        ell[q] = (2*q+1)*L/Q/2 
#     plt.plot(ell,ell*(ell+1)*D_B[n]/(2*np.pi),'g-^') #,label = 'our CMB'

# plt.plot(ell,ell*(ell+1)*CMB[0:Q]/(2*np.pi),'r-x',label = 'real CMB')
# fig2 = plt.figure(2)
# plt.figure(figsize=(20,15))
# Error = [];s=1
# for i in range(s,Q):
#     error = (D_B[0][i]-CMB[i])/CMB[i]*100
#     Error.append(error)
# plt.plot(ell[s:Q],Error)
#np.save('/home/yao/Desktop/EM-smica/ABS/results/Errors_1',Error)
fig3 = plt.figure(3)
plt.figure(figsize=(20,15))
for i in range(Nf):
    evals = Evals.T
    x = np.arange(len(evals[i]))
    plt.scatter(ell,np.log10(evals[i][:]))
    plt.axhline(0,color = 'k')
    
# fig4 = plt.figure(4)
# plt.figure(figsize=(20,15))
# z = []
# for i in range(50):
#     z.append(Evals[i].min())

# plt.plot(ell,z)
# plt.title('The minimum eigenvalues of each l_bin')

# #cl = np.ones(1500)*0.028**2
# #zll = np.ones(1500)*0.015**2
# #ell = np.arange(1500)
# #plt.plot(ell,ell*(ell+1)*cl/2/np.pi,label = '95')
# #plt.plot(ell,ell*(ell+1)*zll/2/np.pi,label = '150')
# plt.legend()
plt.show()
# Out:
# -c:80: RuntimeWarning: invalid value encountered in log10

# %%
for x in evals:
    print x
    exit()
    if x <=0:
        x = None
# Out:
# [  1.09680517e+07   6.27500122e+04   2.88755606e+04   1.86238619e+04
#    1.29114324e+04   9.57969991e+03   8.10347864e+03   6.35656866e+03
#    5.38121326e+03   4.81752764e+03   3.87150357e+03   3.05277077e+03
#    2.70474129e+03   2.48441799e+03   2.08532149e+03   2.00083873e+03
#    1.80744191e+03   1.60004139e+03   1.50377859e+03   1.44942017e+03
#    1.32008908e+03   1.25130064e+03   1.19119224e+03   1.14095601e+03
#    1.14921450e+03   1.14058528e+03   1.11240799e+03   1.09919962e+03
#    1.08692142e+03   1.05443447e+03   1.02756191e+03   1.01892545e+03
#    1.00469554e+03   9.97556079e+02   1.00404542e+03   1.01763495e+03
#    1.01612413e+03   1.02226248e+03   1.02278355e+03   1.02237642e+03
#    1.02197671e+03   1.02628880e+03   1.03012689e+03   1.03557657e+03
#    1.04472840e+03   1.05390707e+03   1.06303095e+03   1.07203776e+03
#    1.07983336e+03   1.08654658e+03]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-28d5b390ee5f> in <module>()
#       2     print x
#       3     exit()
# ----> 4     if x <=0:
#       5         x = None
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
evals.any()
# Out:
# True

# %%
evals[:][:]
# Out:
# array([[  1.09680517e+07,   6.27500122e+04,   2.88755606e+04,
#           1.86238619e+04,   1.29114324e+04,   9.57969991e+03,
#           8.10347864e+03,   6.35656866e+03,   5.38121326e+03,
#           4.81752764e+03,   3.87150357e+03,   3.05277077e+03,
#           2.70474129e+03,   2.48441799e+03,   2.08532149e+03,
#           2.00083873e+03,   1.80744191e+03,   1.60004139e+03,
#           1.50377859e+03,   1.44942017e+03,   1.32008908e+03,
#           1.25130064e+03,   1.19119224e+03,   1.14095601e+03,
#           1.14921450e+03,   1.14058528e+03,   1.11240799e+03,
#           1.09919962e+03,   1.08692142e+03,   1.05443447e+03,
#           1.02756191e+03,   1.01892545e+03,   1.00469554e+03,
#           9.97556079e+02,   1.00404542e+03,   1.01763495e+03,
#           1.01612413e+03,   1.02226248e+03,   1.02278355e+03,
#           1.02237642e+03,   1.02197671e+03,   1.02628880e+03,
#           1.03012689e+03,   1.03557657e+03,   1.04472840e+03,
#           1.05390707e+03,   1.06303095e+03,   1.07203776e+03,
#           1.07983336e+03,   1.08654658e+03],
#        [  4.50388075e+04,   5.71526006e+03,   3.86775601e+03,
#           3.15518066e+03,   2.86962540e+03,   2.52450932e+03,
#           2.23182286e+03,   1.89906488e+03,   1.57342941e+03,
#           1.28205274e+03,   9.96393498e+02,   7.81098202e+02,
#     3.53551583e-04  -2.03790147e-02  -1.19697389e-02]
#  [  1.02628880e+03   1.21280524e+02   4.30043927e+00  -4.62938150e-02
#    -1.78633793e-02  -3.66907717e-02  -2.96763233e-02]
#  [  1.03012689e+03   1.09159027e+02   4.23360563e+00  -4.90505106e-02
#    -2.41978378e-02  -2.86672957e-02  -3.52076845e-02]
#  [  1.03557657e+03   1.02056858e+02   4.15603140e+00  -6.34012972e-02
#    -2.93643919e-02  -3.88758904e-02  -4.91672180e-02]
#  [  1.04472840e+03   9.92802131e+01   3.94669198e+00  -3.91048998e-02
#    -6.01247039e-02  -4.86799179e-02  -5.34212471e-02]
#  [  1.05390707e+03   9.15674982e+01   4.30109767e+00  -4.20899579e-02
#    -7.07276210e-02  -5.44414649e-02  -6.22126018e-02]
#  [  1.06303095e+03   8.34333170e+01   4.71374750e+00  -4.24671847e-02
#    -7.60845051e-02  -5.65684001e-02  -6.46615788e-02]
#  [  1.07203776e+03   7.91191322e+01   4.59013939e+00  -8.88651855e-02
#    -5.30680683e-02  -6.00007936e-02  -7.09464174e-02]
#  [  1.07983336e+03   7.47036900e+01   4.68234031e+00  -6.74890886e-02
#    -7.24852590e-02  -9.41594062e-02  -8.41680608e-02]
#  [  1.08654658e+03   6.73360470e+01   4.61294722e+00  -1.13009281e-01
#    -8.50660470e-02  -9.41502004e-02  -9.58502264e-02]]

# %%
from NPTFit import create_mask as cm
mask = cm.make_mask_total(nside=512,l_mask = False,b_mask = True, b_deg_min = -10, b_deg_max = 10)
hp.mollview(ex,title='',min=0,max=1) #cbar=Fals
total = np.load('/home/yao/Desktop/EM-smica/ABS/simulation/total_map.npy')
cmb = np.load('/home/yao/Desktop/EM-smica/ABS/simulation/cmb_map.npy')
total_masked = hp.ma(total[0][0])
total_masked.mask = mask
cmb_masked = hp.ma(cmb[0][0])
cmb_masked.mask = mask
hp.mollview(total_masked)
hp.mollview(cmb_masked)

# %%
example2 = cm.make_mask_total(nside = 256,band_mask = True, band_mask_range = 20)
hp.mollview(example2, title='')

# %%
2070528/3145728.0
# Out:
# 0.658203125

# %%
float(len(example2[example2 == False]))/len(example2)
# Out:
# 0.6575520833333334

# %%
len(example2)
# Out:
# 3145728

# %%
example3a = cm.make_mask_total(
                               b_mask = True, b_deg_min = -30, b_deg_max = 30)
hp.mollview(example3a,title='')

# %%
total = np.load('/home/yao/Desktop/EM-smica/ABS/simulation/total_map.npy')
def Mask(sky_map):
    mask = np.empty_like(total);mask_i = cm.make_mask_total(nside,b_mask=True, b_deg_min = -10, b_deg_max = 10)
    for i in range(Nf):
        for j in range(3):
            mask[i][j][:]=mask_i[:]
   
    map_masked = hp.ma(sky_map)
    map_masked.mask = mask
    return map_masked

# %%
nside = 512
total_masked = Mask(total)

# %%
hp.mollview(total_masked[0,1])

# %%
from NPTFit import create_mask as cm
mask = cm.make_mask_total(512,b_mask=True, b_deg_min = -10, b_deg_max = 10)
z = np.ones(len(mask))
fr = 1-np.dot(mask,z)/len(mask) #masked

# %%
cmb = np.load('../simulation/total_map.npy')
cmb_masked = Mask(cmb)

# %%
hp.mollview(cmb_masked[4,0])
